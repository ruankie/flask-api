# %%
import pandas as pd
import numpy as np
from src import utilities

# %%
utilities.greet()
# Out:
# Hello World!

# %%
data = np.random.normal(loc=0.0, scale=1.0, size=(25,))
df = pd.Series(data)
df.plot(figsize=(14,4))
# Out:
# <AxesSubplot:>
